# %% [markdown]
# # Personal Spotify Analysis

# %% [markdown]
# I chose to do this anaylsis because I wanted to learn more about utilizing and troubleshooting APIs and working with JSON files. Additionally, I felt looking at my personal spotify account would allow for some interesting analysis to see the evolution of my muscial tastes through time.

# %%
import sys
import spotipy
import spotipy.util as util
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Authentication of my account

# %% [markdown]
# Through spotify's web developer portal, it is very easy to get quickly authenticated for building both commercial and non-commercial apps. Upon being approved, you are generated an ID along with Secret ID. I was redirected to my redirect_url, then allowing my to send API requests.

# %%
username = sys.argv[1]
scope = 'user-library-read'

# %%
token = util.prompt_for_user_token(username,scope,client_id='96b658e2c3944ac2bcc51b53b164032e',
                                   client_secret='14750308b83e47bbb9567d20b1d90c78',
                                   redirect_uri='http://google.com/')

# %% [markdown]
# ### Creating API Requests

# %%
sp = spotipy.Spotify(auth=token)

# %%
my_user = sp.current_user()

# %% [markdown]
# ### My saved albums

# %%
??sp.current_user_followed_artists

# %%
??sp.current_user_saved_albums

# %%
saved_albums = sp.current_user_saved_albums(offset=20)

# %%
len(saved_albums['items'])
# Out:
# 12

# %%
#saved_albums_artists = [(saved_albums['items'][i]['album']['artists'][0]['name']) for i in range(len(saved_albums['items']))]

# %%
len_albums = True
ind = 0
saved_albums_artists = []

while len_albums == True:
    saved_albums = sp.current_user_saved_albums(offset=ind)
    if len(saved_albums['items']) == 20:
        ind += 20
        for i in range(len(saved_albums['items'])):
            artist = saved_albums['items'][i]['album']['artists'][0]['name']
            saved_albums_artists.append(artist)
    else:
        for i in range(len(saved_albums['items'])):
            artist = saved_albums['items'][i]['album']['artists'][0]['name']
            saved_albums_artists.append(artist)
        len_albums = False

# %%
from collections import Counter
count_album_artists = Counter(saved_albums_artists)

# %%
artist_name = []
artist_count = []
for artist, count in count_album_artists.items():
    artist_name.append(artist)
    artist_count.append(count)

# %%
plt.barh(artist_name, artist_count, color = 'red')
plt.title('Number of Saved Albums by Artist')
plt.show()

# %% [markdown]
# ### My saved songs

# %% [markdown]
# There is a limit of 20 items that can be requested at a given time. There is a parameter in the object that can continue to the next artist given the last one in the previous API request

# %%
saved_songs['items'][19]['track']['name']
# Out:
# 'Strange American Dream'

# %%
saved_songs['items']
# Out:
# [{'added_at': '2019-12-21T20:24:00Z',
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wUjUUtkb5lvLKcGKsKqsR'},
#       'href': 'https://api.spotify.com/v1/artists/2wUjUUtkb5lvLKcGKsKqsR',
#       'id': '2wUjUUtkb5lvLKcGKsKqsR',
#       'name': 'Alessia Cara',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wUjUUtkb5lvLKcGKsKqsR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
# ...
